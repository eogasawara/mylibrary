# %% [markdown]
# # Active Document

# %%
print("Hello World")
X <- 1:10
# Out:
# [1] "Hello World"

# %%
Y <- X + 1

# %% [markdown]
# LaTeX expressions $Y \gets X + 1$ can be used

# %%
plot(X,Y)
# Out:
# plot without title
